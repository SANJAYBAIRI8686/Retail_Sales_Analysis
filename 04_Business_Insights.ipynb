# %%
print("="*80)
print("RETAIL SALES ANALYSIS - BUSINESS INSIGHTS SUMMARY")
print("="*80)

print("\n📊 KEY FINDINGS:\n")
print("1. TOTAL PERFORMANCE:")
print("   • Total Orders: 9,994")
print("   • Total Revenue: $2,297,201")
print("   • Total Profit: $286,397")
print("   • Average Order Value: $229.86")

print("\n2. GROWTH TRENDS:")
print("   • Year-over-year growth: XX%")
print("   • Peak sales month: December (holiday season)")
print("   • Lowest sales month: February")

print("\n3. TOP PERFORMERS:")
print("   • Best Category: Technology ($836K in sales)")
print("   • Best Product: [Product Name]")
print("   • Best Region: West ($725K in sales)")

print("\n4. CUSTOMER INSIGHTS:")
print("   • Total Unique Customers: 793")
print("   • Top 10% customers generate 50%+ of revenue")
print("   • Average customer orders: 12.6 times")

print("\n5. PROFIT ANALYSIS:")
print("   • Overall profit margin: 12.5%")
print("   • Technology has highest margin")
print("   • Discounts reduce profit margin by XX%")

print("\n💡 RECOMMENDATIONS:\n")
print("1. Focus on Technology category (highest profit margin)")
print("2. Implement VIP program for top 10% customers")
print("3. Reduce heavy discounting (hurts profitability)")
print("4. Expand in West region (strongest performance)")
print("5. Target campaigns for November-December (peak season)")

print("\n" + "="*80)
# Out:
# ...
# RETAIL SALES ANALYSIS - BUSINESS INSIGHTS SUMMARY
# ...
#
# 📊 KEY FINDINGS:
#
# 1. TOTAL PERFORMANCE:
#    • Total Orders: 9,994
#    • Total Revenue: $2,297,201
#    • Total Profit: $286,397
#    • Average Order Value: $229.86
#
# 2. GROWTH TRENDS:
#    • Year-over-year growth: XX%
#    • Peak sales month: December (holiday season)
#    • Lowest sales month: February
#
# 3. TOP PERFORMERS:
#    • Best Category: Technology ($836K in sales)
#    • Best Product: [Product Name]
#    • Best Region: West ($725K in sales)
#
# 4. CUSTOMER INSIGHTS:
#    • Total Unique Customers: 793
#    • Top 10% customers generate 50%+ of revenue
#    • Average customer orders: 12.6 times
#
# 5. PROFIT ANALYSIS:
#    • Overall profit margin: 12.5%
#    • Technology has highest margin
#    • Discounts reduce profit margin by XX%
#
# 💡 RECOMMENDATIONS:
#
# 1. Focus on Technology category (highest profit margin)
# 2. Implement VIP program for top 10% customers
# 3. Reduce heavy discounting (hurts profitability)
# ...
